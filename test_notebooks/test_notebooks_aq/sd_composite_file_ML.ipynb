# %%
# Import packages/ modules
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import earthpy as et
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import datetime
from textwrap import wrap

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

# %%
# Conditional statement to check and set working directory. 
ea_path = os.path.join(et.io.HOME, 'earth-analytics')

if os.path.exists(ea_path):
    os.chdir(ea_path)
    print("working directory is set to earth-analytics") 
else:     
    print("This path does not exist")
    
# Set base path to download data 
base_path = os.path.join(ea_path, "data")
base_path
# Out:
# working directory is set to earth-analytics
# 'C:\\Users\\bina_\\earth-analytics\\data'

# %%
# Files to download for further analysis
# Define relative path to files
file_path1 = os.path.join(base_path,"output_figures","sandiego_2014_fires", "air_quality_csv",                     
                         "sd_combined_data_2014.csv")

# To check if path is created
os.path.exists(file_path1)
# Out:
# True

# %%
# Import csv files into dataframe and ensure date time is imported properly.
sd_2014_df = pd.read_csv(file_path1, parse_dates=['Date Local'],
                                index_col=['Date Local'])
sd_2014_df.head()
# Out:
#             Temp_mean  temp_sem    RH_mean     RH_sem   Pres_mean  Pres_sem  \
# Date Local
# 2014-01-01  55.489583  1.309491  42.916666  13.112560  999.845833       NaN
# 2014-01-02  58.156250  1.655276  40.027778  10.834838  998.504167       NaN
# 2014-01-03  57.661458  1.320798  44.597222   9.838550  996.229167       NaN
# 2014-01-04  57.651042  0.626978  54.402778  12.489448  996.170833       NaN
# 2014-01-05  59.765625  1.247342  38.708333  11.079756  999.791667       NaN
#
#             wind_mean   wind_sem  O3_ppm_mean  O3_ppb_mean    O3_sem  \
# Date Local
# 2014-01-01  90.233565  22.277571     0.022278    22.278182  0.003167
# 2014-01-02  84.944213  20.699350     0.018206    18.205909  0.002744
# 2014-01-03  81.395833  19.529677     0.017753    17.753455  0.002696
# 2014-01-04  79.122222  19.302119     0.021888    21.887636  0.002622
# 2014-01-05  70.098843  16.718359     0.024241    24.240636  0.002934
#
#              NO2_mean   NO2_sem  PM2.5_mean  PM2.5_sem   CO_mean    CO_sem
# Date Local
# 2014-01-01  18.373518  2.823354   60.135417   7.557420  0.902183  0.177094
# 2014-01-02  22.438928  3.099723   20.370473   1.022282  0.947633  0.069862
# 2014-01-03  24.411817  3.093049   19.813596   3.520073  0.970017  0.077705
# 2014-01-04  20.027809  2.733161   23.810417   0.579792  0.825603  0.055081
# 2014-01-05  18.920666  3.044514   20.032639   0.828190  0.841809  0.070696

# %%
# import matplotlib.pyplot as plt

# import pandas
# from pandas.tools import plotting

from statsmodels.formula.api import ols

# %%
# # Express the names as categories
# categories = pd.plotting.Categorical(sd_2014_df)

# # The parameter 'c' is passed to plt.scatter and will control the color
# plotting.scatter_matrix(data, c=categories.codes, marker='o')

# fig = plt.gcf()
# fig.suptitle("blue: setosa, green: versicolor, red: virginica", size=13)

# %%
sd_2014_df.reset_index(inplace = True)
sd_2014_df.head()
# pd.plotting.scatter_matrix(sd_2014_df)
# Out:
#   Date Local  Temp_mean  temp_sem    RH_mean     RH_sem   Pres_mean  Pres_sem  \
#       NO2_sem  PM2.5_mean  PM2.5_sem   CO_mean    CO_sem
# 0    2.823354   60.135417   7.557420  0.902183  0.177094
# 1    3.099723   20.370473   1.022282  0.947633  0.069862
# 2    3.093049   19.813596   3.520073  0.970017  0.077705
# 3    2.733161   23.810417   0.579792  0.825603  0.055081
# 4    3.044514   20.032639   0.828190  0.841809  0.070696
# ..        ...         ...        ...       ...       ...
# 360  2.690327   10.583333   2.071035  0.593211  0.026511
# 361  2.222872   14.153373   2.414931  0.557922  0.074743
# 362  1.702158   13.941591   2.176999  0.646429  0.113613
# 363  1.441519    6.630470   0.282811  0.424365  0.036886
# 364  1.697819   16.916244   3.297116  0.428748  0.052182
#
# [365 rows x 17 columns]

# %%
# remove index on data  and remove NAN
# pd.plotting.Categorical.scatter_matrix(sd_2014_df)
colors = ["yellow", "red", "green"]
pd.plotting.scatter_matrix(sd_2014_df, c=sd_2014_df.Survived.apply(lambda x:colors[x])
)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-8113ac60374e> in <module>
#       2 # pd.plotting.Categorical.scatter_matrix(sd_2014_df)
#       3 colors = ["yellow", "red", "green"]
# ----> 4 pd.plotting.scatter_matrix(sd_2014_df, c=sd_2014_df.Survived.apply(lambda x:colors[x])
#       5 )
#       6
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Survived'

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
file_path2 = os.path.join(base_path,"Stock_data", "datasets_4458_8204_winequality-red.csv")
file_path3 = os.path.join(base_path,"Stock_data", "operations.csv")
# To check if path is created
os.path.exists(file_path3)
# Out:
# True

# %%
dataset= pd.read_csv(file_path3)
dataset.shape
# Out:
# C:\Users\bina_\Miniconda3\envs\earth-analytics-python\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (7,8,11,13,31,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (178281, 46)

# %%
dataset2= pd.read_csv(file_path2)
dataset2.shape
# Out:
# (1599, 12)

# %%
dataset.describe()
# Out:
#           Mission ID  Takeoff Longitude  Target Latitude  Target Longitude  \
# count  178281.000000        2980.000000    169565.000000     169543.000000
# mean    89414.547041         220.618627        38.067793         43.340213
# std     51649.744549         454.046956        18.711405         59.681160
# min         1.000000        -177.328611       -37.416667       -179.451285
# 25%     44571.000000          14.400000        26.250000          7.620000
# 50%     89540.000000          29.851389        47.500000         11.330000
# 75%    134171.000000          96.133222        50.930000         97.400000
# max    178742.000000        1355.000000      1108.000000       1000.650000
#
#        Altitude (Hundreds of Feet)  Airborne Aircraft  Attacking Aircraft  \
# count                120826.000000       82242.000000       125108.000000
# mean                    139.026812          12.329771           10.218899
# std                     186.818278          12.514833           11.246399
# min                       0.000000           0.000000            0.000000
# 25%                      70.000000           2.000000            2.000000
# 50%                     122.000000          11.000000            7.000000
# 75%                     223.000000          17.000000           12.000000
# max                   40000.000000         332.000000          332.000000
#
#        Bombing Aircraft  Aircraft Returned  Aircraft Failed  ...  \
# count      81612.000000         133.000000       247.000000  ...
# mean          12.347486           2.157895         4.275304  ...
# std           12.573549           1.369816         5.924758  ...
# min            0.000000           1.000000         1.000000  ...
# 25%            2.000000           1.000000         1.000000  ...
# 50%           11.000000           2.000000         2.000000  ...
# 75%           18.000000           3.000000         4.000000  ...
# max          332.000000           7.000000        48.000000  ...
#
#        High Explosives Weight (Tons)  Incendiary Devices  \
# count                  146201.000000         3283.000000
# mean                       23.911995          132.001965
# std                        90.092020          498.596761
# min                         0.000000            0.000000
# 25%                         2.000000            7.000000
# 50%                         9.000000           14.000000
# 75%                        30.000000           32.000000
# max                     20000.000000         4875.000000
#
#        Incendiary Devices Weight (Pounds)  Incendiary Devices Weight (Tons)  \
# count                          356.000000                      25732.000000
# mean                         19962.732022                         21.527213
# std                          45331.714255                         66.692639
# min                              0.000000                          0.000000
# 25%                            218.750000                          1.000000
# 50%                           2640.000000                          6.000000
# 75%                          12500.000000                         18.000000
# max                         420000.000000                        999.000000
#
#        Fragmentation Devices  Fragmentation Devices Weight (Pounds)  \
# count            5768.000000                             194.000000
# mean              102.684560                            2065.630928
# std               158.941650                            2424.138566
# min                 0.000000                               0.000000
# 25%                10.000000                             598.400000
# 50%                38.461538                            1500.000000
# 75%               133.333333                            2400.000000
# max              3000.000000                           20640.000000
#
#        Fragmentation Devices Weight (Tons)  Total Weight (Pounds)  \
# count                         16902.000000           2.119000e+03
# mean                             12.017136           1.237718e+04
# std                              27.221410           2.064155e+05
# min                               0.000000           0.000000e+00
# 25%                               1.000000           2.100000e+03
# 50%                               3.000000           5.200000e+03
# 75%                              12.000000           1.080000e+04
# max                             900.000000           9.500000e+06
#
#        Total Weight (Tons)      Source ID
# count        166508.000000  174236.000000
# mean             25.760326  152670.902322
# std              90.643876  105544.795936
# min               0.000000       1.000000
# 25%               2.000000   53476.500000
# 50%               9.290000  167604.500000
# 75%              31.000000  211284.250000
# max           20000.000000  699625.000000
#
# [8 rows x 23 columns]

# %%
# dataset.plot(x='MinTemp', y='MaxTemp', style='o')  
# plt.title('MinTemp vs MaxTemp')  
# plt.xlabel('MinTemp')  
# plt.ylabel('MaxTemp')  
# plt.show()

# %%
dataset2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
dataset2.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
#Once the above code is executed, all the columns should give False, 
# In case for any column you find True result, 
#then remove all the null values from that column using below code.
dataset2 = dataset.fillna(method='ffill')

# %%
#Our next step is to divide the data into “attributes” and “labels”. 
#X variable contains all the attributes/features and y variable contains labels.

X = dataset2[['fixed acidity', 'volatile acidity', 'citric acid', 
              'residual sugar', 'chlorides', 'free sulfur dioxide', 
              'total sulfur dioxide', 'density', 'pH', 
              'sulphates','alcohol']].values
y = dataset2['quality'].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-554a228cb0cd> in <module>
#       2 #X variable contains all the attributes/features and y variable contains labels.
#       3
# ----> 4 X = dataset2[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates','alcohol']].values
#       5 y = dataset2['quality'].values
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',\n       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',\n       'pH', 'sulphates', 'alcohol'],\n      dtype='object')] are in the [columns]"

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset['quality'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'quality'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-ab82c6777db0> in <module>
#       1 plt.figure(figsize=(15,10))
#       2 plt.tight_layout()
# ----> 3 seabornInstance.distplot(dataset['quality'])
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~\Miniconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'quality'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-bb365302dcaa> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#
# NameError: name 'X' is not defined
